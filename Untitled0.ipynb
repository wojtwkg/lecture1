# %% [markdown]
# <a href="https://colab.research.google.com/github/wojtwkg/lecture1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('Salary Data (2).csv')


plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Education Level', y='Salary', hue='Gender')

plt.title('Salary Distribution by Education Level and Gender')
plt.xlabel('Education Level')
plt.ylabel('Salary')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
